# %% [markdown]
# <a href="https://colab.research.google.com/github/mojtabaSefidi/Comparative-Opinion-Summarization-Data-Generator/blob/main/Main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from data_collector import *
from gpt_functions import *

# %% [markdown]
# ### Get All Hotels

# %%
URL = 'https://www.eghamat24.com/QeshmHotels.html'
Hotels_Qeshm = get_hotels_city(URL)
Hotels_Qeshm
# Out:
# {'هتل آرتا قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/ArtaHotel.html'},
#  'هتل آرتمیس قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/ArtemisHotel.html'},
#  'هتل آپارتمان پلاس قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/PlusHotel.html'},
#  'هتل ریحان قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/ReihanHotel.html'},
#  'هتل ویهان قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/VihanHotel.html'},
#  'هتل آتامان قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/AtamanHotel.html'},
#  'هتل ارم قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/EramHotel.html'},
#  'هتل آپارتمان الیت قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/elitHotel.html'},
#  'هتل بوتیک فولتون قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/FultonHotel.html'},
#  'هتل آسانا قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/AsanaHotel.html'},
#  'هتل سینگو قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/SingoHotel.html'},
# ...

# %% [markdown]
# ### Add Detail of Hotels

# %%
Hotels_Qeshm = add_details(Hotels_Qeshm)
Hotels_Qeshm
# Out:
# {'هتل آرتا قشم': {'Link': 'https://www.eghamat24.com/QeshmHotels/ArtaHotel.html',
#   'Address': 'قشم، بلوار شهید بهشتی، رو به روی منازل مسکونی علی بن ابی طالب',
#   'Star': 'هتل چهار ستاره',
#   'Average_Scores': {'امکانات هتل': 7.1,
#    'قیمت': 7.0,
#    'کیفیت اتاق ها': 7.3,
#    'موقعیت مکانی': 8.6,
#    'پروتکل های بهداشتی': 7.9},
#   'Reviews': [{'Name': 'فرشته ب',
#     'Date': '2023-11-23 16:21:14',
#     'Rate': '10',
#     'Purpose': 'خانوادگی',
#     'Comment': 'عالی بود .خیلی لذت بردیم به مدت دو شب همراه همسرم اقامت داشتیم صبحانه عالی .اتاق عالی .برخورد پرسنل عالی بود اتاق تمیز .ملحفه تمیز .و برای ما سکوت و آرامش هم مهم بود که واقعا راضی بودیم خانمی که اتاق رو تحویل دادیم هم خیلی محترمانه برخورد داشتند یک نکته منفی داشت برخورد خانم پذیرش زیاد محترمانه نبود موقعی که گفتم لطفا اتاق جایی باشه که ساکت باشه گفتند که همین اتاق مونده و مثلا همینه که هست ولی خوب میتونستند مودبانه و محترمانه جواب بدند .هتلی با اون همه امتیازات مثبت واقعا امتیاز منفی نباید داشته باشه .'},
# ...

# %% [markdown]
# ### Creating Prompts

# %%
Hotel_A = 'هتل آزادی قشم'
Hotel_B = 'هتل شهریار قشم'

initial_prompt_1 = '''
I want to compare two hotels (Hotel_A and Hotel_B) based on their similarities and differences. I will give you their reviews, and you should output three {Language} summaries for me based on the reviews.
The language of reviews is Persian, and each generated summary should be one sentence. To generate the output, follow these steps:
1. if there exist duplicate reviews, only use one of them
2. generate the first summary based on the similarities between Hotel A_and Hotel_B. You should use the information shared aspects and features between Hotel_A and Hotel_B and generate a summary.
Start this summary with 'Similarity_AB: '
3. Generate the second summary based on aspects and characteristics of Hotel_A that are exclusive to Hotel_A. Users mentioned these features and aspects only in reviews of Hotel_A, and Hotel_B doesn't have these aspects. Start this summary with 'Comparative_A: '
4. generate the third summary based on aspects and characteristics of Hotel_B that are exclusive to Hotel_B. Users mentioned these features and aspects only in reviews of Hotel_B, and Hotel_A doesn't have these aspects. Start this summary with 'Comparative_B: '
Note that 'back_slash n' means line break. Only use the information that appeared in reviews to generate reviews.

'''.format(Language = 'English')

initial_prompt_2 = '''
I want to compare two hotels (Hotel_A and Hotel_B) based on their similarities and differences. I will give you their reviews, and you should output three {Language} summaries for me based on the reviews.
The language of reviews is Persian, and each generated summary should be one sentence. To generate the output, follow these steps:
1. if there exist duplicate reviews, only use one of them
2. generate the first summary based on the similarities between Hotel A_and Hotel_B. You should use the information shared aspects and features between Hotel_A and Hotel_B and generate a summary.
Start this summary with 'Similarity_AB: '
3. Generate the second summary based on aspects and characteristics of Hotel_A that are exclusive to Hotel_A. Users mentioned these features and aspects only in reviews of Hotel_A, and Hotel_B doesn't have these aspects. Start this summary with 'Comparative_A: '
4. generate the third summary based on aspects and characteristics of Hotel_B that are exclusive to Hotel_B. Users mentioned these features and aspects only in reviews of Hotel_B, and Hotel_A doesn't have these aspects. Start this summary with 'Comparative_B: '
Note that 'back_slash n' means line break. Only use the information that appeared in reviews to generate reviews.

'''.format(Language = 'Persian')

prompt_1 = generate_prompt(Hotels_Qeshm, Hotel_A, Hotel_B, initial_prompt=initial_prompt_1)
prompt_2 = generate_prompt(Hotels_Qeshm, Hotel_A, Hotel_B, initial_prompt=initial_prompt_2)

# %% [markdown]
# ### Build GPT Client

# %%
api_key = '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'
client = build_client(api_key)

# %% [markdown]
# ### Comparative Summaries (English)

# %%
output_english = generate(client, prompt=prompt_1)
print(output_english)
# Out:
# Similarity_AB: Both Hotel_A and Hotel_B have good staff and a friendly atmosphere.
# Comparative_A: Hotel_A has a good location and a great view, but some parts of the hotel were under renovation and it was cold in the morning.
# Comparative_B: Hotel_B has polite staff and a clean environment, but the rooms are small and the bathroom facilities are not satisfactory.

# %% [markdown]
# ### Comparative Summaries (Persian)

# %%
output_persian = generate(client, prompt=prompt_2)
print(output_persian)
# Out:
# Similarity_AB: هتل آزادی قشم و هتل شهریار قشم دارای پرسنلی خوب و خونگرم هستند و بازسازی شده‌اند.
#
# Comparative_A: هتل آزادی قشم جای خوبی دارد که رو به دریاست و منطقه‌ای دنج و آرام است. همچنین برخورد پرسنل بسیار خوب است.
#
# Comparative_B: هتل شهریار قشم تمیز است و فاصله ۲۰ دقیقه‌ای با پاساژ‌های خرید دارد. همچنین پرسنل آن با احترام برخورد کرده و به نظافت هتل توجه مناسبی دارد.
